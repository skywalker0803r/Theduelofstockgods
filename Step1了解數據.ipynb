# %%
import pandas as pd
df = pd.read_csv('38_Training_Data_Set_V2/training.csv',nrows=20000)  # 或 Excel, JSON 等
df
# Out:
#              ID  外資券商_分點進出  外資券商_分點買賣力  外資券商_分點成交力(%)  外資券商_分點吃貨比(%)  \
# 0          TR-1     1.2227      2.8303         1.2789         0.5707
# 1          TR-2     1.2297      2.8303         1.7995         1.1170
# 2          TR-3     1.3127      1.2826         1.4307         5.0469
# 3          TR-4     1.2219         NaN         1.2413         0.5313
# 4          TR-5     0.7988      1.0454         0.8652         1.8842
# ...         ...        ...         ...            ...            ...
# 19995  TR-19996     1.2840      1.4115         1.3156         0.9453
# 19996  TR-19997     1.2219         NaN         1.2413         0.5313
# 19997  TR-19998     1.2002      0.2832         0.7836         0.6857
# 19998  TR-19999     1.2227      2.8303         1.2849         0.5770
# 19999  TR-20000     1.2219         NaN         1.2413         0.5313
#
#        外資券商_分點出貨比(%)  外資券商_前1天分點進出  外資券商_前1天分點買賣力  外資券商_前1天分點成交力(%)  \
# 0             0.5329        1.2219         1.2686            1.2255
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Columns: 10214 entries, ID to 飆股
# dtypes: float64(10212), int64(1), object(1)
# memory usage: 1.5+ GB

# %%
df.describe()
# Out:
#           外資券商_分點進出    外資券商_分點買賣力  外資券商_分點成交力(%)  外資券商_分點吃貨比(%)  \
# count  20000.000000  13961.000000   19753.000000   19753.000000
# mean       1.229361      1.237829       1.232184       1.231945
# std        1.079986      0.995260       1.000565       1.001007
# min      -34.237900     -0.336300      -5.902600       0.531300
# 25%        1.215700      0.443100       0.981600       0.531300
# 50%        1.221900      1.247000       1.241300       0.790400
# 75%        1.228100      2.038600       1.486700       1.562900
# max       43.199300      2.830300       8.385200       8.028400
#
#        外資券商_分點出貨比(%)  外資券商_前1天分點進出  外資券商_前1天分點買賣力  外資券商_前1天分點成交力(%)  \
# count   19753.000000  20000.000000   14028.000000      19757.000000
# mean        1.220840      1.211246       1.239797          1.223722
# std         1.003444      0.949386       1.341970          0.164922
# min         0.532900    -29.521300     -18.268000         -7.614800
# ...

# %%
df.to_feather('Step1.feather')
