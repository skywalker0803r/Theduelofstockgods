# %%
import pandas as pd


df = pd.read_csv('38_Public_Test_Set_and_Submmision_Template_V2/38_Public_Test_Set_and_Submmision_Template_V2/public_x.csv')
df
# Out:
#              ID  外資券商_分點進出  外資券商_分點買賣力  外資券商_分點成交力(%)  外資券商_分點吃貨比(%)  \
# 0          PU-1     1.2219         NaN         1.2413         0.5313
# 1          PU-2     1.2219         NaN         1.2413         0.5313
# 2          PU-3     3.2984      1.4356         1.8457         3.5096
# 3          PU-4     1.2211     -0.3363         0.7311         0.5313
# 4          PU-5     1.5689      1.5861         1.8969         2.4814
# ...         ...        ...         ...            ...            ...
# 25103  PU-25104     1.2219         NaN         1.2413         0.5313
# 25104  PU-25105     1.3073      1.2751         1.3396         3.4861
# 25105  PU-25106     1.2041     -0.3363         0.3484         0.5313
# 25106  PU-25107     1.0892      0.6864         0.8777         0.8795
# 25107  PU-25108     1.7024      1.8501         2.0542         2.0776
#
#        外資券商_分點出貨比(%)  外資券商_前1天分點進出  外資券商_前1天分點買賣力  外資券商_前1天分點成交力(%)  \
# 0             0.5329        1.2258            NaN            1.2238
# ...

# %%
df.to_feather('pub_x.feather')
