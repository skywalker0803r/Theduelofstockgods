# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

# 標準化
df = pd.read_feather('Step3.feather')
x_col = df.drop(['ID','飆股'],axis=1).columns.tolist()
y_col = '飆股'
scaler = StandardScaler()
df[x_col] = scaler.fit_transform(df[x_col])
df
# Out:
#              ID  外資券商_分點進出  外資券商_分點成交力(%)  外資券商_分點吃貨比(%)  外資券商_分點出貨比(%)  \
# 0          TR-1  -0.006168       0.046869      -0.658441      -0.683780
# 1          TR-2   0.000314       0.570431      -0.109934      -0.683780
# 2          TR-3   0.077169       0.199532       3.835843       3.504417
# 3          TR-4  -0.006909       0.009055      -0.698000      -0.683780
# 4          TR-5  -0.398683      -0.369185       0.660366       1.011853
# ...         ...        ...            ...            ...            ...
# 19995  TR-19996   0.050593       0.083778      -0.282328      -0.357735
# 19996  TR-19997  -0.006909       0.009055      -0.698000      -0.683780
# 19997  TR-19998  -0.027002      -0.451249      -0.542976      -0.067951
# 19998  TR-19999  -0.006168       0.052903      -0.652115      -0.683780
# 19999  TR-20000  -0.006909       0.009055      -0.698000      -0.683780
#
#        外資券商_前1天分點進出  外資券商_前1天分點買賣力  外資券商_前1天分點成交力(%)  外資券商_前1天分點吃貨比(%)  \
# 0          0.011222   2.562837e-02          0.010840         -0.704546
# 1          0.021123   1.809865e-01          0.256092         -0.157304
# 2         -0.112019  -1.129810e-02          0.168851          1.842871
# 3          0.015330  -1.975741e-16          0.000469         -0.704546
# 4         -0.527139  -9.476083e-02         -0.320433          0.304306
# ...             ...            ...               ...               ...
# 19995      0.418021   1.121370e-02          0.129806          1.078122
# 19996      0.015330  -1.975741e-16          0.000469         -0.704546
# 19997      0.011222  -1.120516e+00         -0.279558         -0.683188
# 19998      0.016173   2.438950e-01          0.015111         -0.672913
# 19999      0.015330  -1.975741e-16          0.000469         -0.704546
#
#        外資券商_前1天分點出貨比(%)  ...  上市加權指數前15天成交量  上市加權指數前16天成交量  上市加權指數前17天成交量  \
# 0             -0.575513  ...      -0.903553      -1.083851      -0.977767
# 1             -0.525177  ...      -0.274871      -0.476803      -0.758067
# 2              2.241502  ...      -0.724043      -0.437163       0.036945
# 3             -0.684190  ...       0.554715      -0.371927      -0.418432
# 4              1.091580  ...      -0.476571      -0.353900      -0.350825
# ...                 ...  ...            ...            ...            ...
# 19995         -0.590323  ...      -0.570306      -0.399515      -0.551750
# 19996         -0.684190  ...      -0.336664      -0.340852       0.143499
# 19997         -0.560102  ...       1.148670       0.531025       0.600374
# 19998         -0.684190  ...       0.058775       0.277549       0.231379
# 19999         -0.684190  ...      -0.749218      -0.669724      -1.232019
#
#        上市加權指數前18天成交量  上市加權指數前19天成交量  上市加權指數前20天成交量  上市加權指數5天成交量波動度  \
# 0          -0.901911      -0.779253      -1.169092       -1.021629
# 1          -0.751782      -0.561367      -1.086892       -0.811138
# 2          -0.311363      -0.067699       0.256187       -1.024320
# 3          -0.388322       0.431369       0.349075       -0.430120
# 4          -0.470365      -0.990540      -0.734617        0.617255
# ...              ...            ...            ...             ...
# 19995      -0.676817      -0.464574      -0.739711       -0.987245
# 19996       0.374485      -0.320283      -0.527667        0.135377
# 19997       0.332018       0.642056       0.820905        1.819410
# 19998      -0.058556      -0.222289      -0.178189        0.065811
# 19999      -0.865425      -0.532669      -0.270477       -0.848811
#
#        上市加權指數10天成交量波動度  上市加權指數20天成交量波動度  飆股
# 0            -1.084360        -0.985456   0
# 1            -0.637027        -0.903632   0
# 2            -0.756336        -0.450013   0
# 3            -1.011566        -0.487747   0
# 4             0.267809        -0.313402   0
# ...                ...              ...  ..
# 19995        -1.054961        -1.198948   0
# 19996         0.453971        -0.086895   0
# 19997         1.892727         1.451030   0
# 19998         1.622193         0.434322   0
# 19999        -1.063821        -0.984750   0
#
# [20000 rows x 10177 columns]

# %%
df.to_feather('Step4.feather')
