# %%
import pandas as pd

df = pd.read_csv('1.csv')
df['飆股'].value_counts()
# Out:
# 飆股
# 1    1254
# Name: count, dtype: int64

# %%
df_train = pd.read_csv('38_Training_Data_Set_V2/training.csv',nrows=10000)
df_train['飆股'].value_counts()
# Out:
# 飆股
# 0    9931
# 1      69
# Name: count, dtype: int64

# %%
combined = pd.concat([df, df_train[df_train['飆股']==0].sample(1254)], axis=0)
combined
# Out:
#             ID  外資券商_分點進出  外資券商_分點買賣力  外資券商_分點成交力(%)  外資券商_分點吃貨比(%)  \
# 0       TR-191     1.9198      2.4793         1.9867         1.4249
# 1       TR-193     1.2219         NaN         1.2413         0.5313
# 2     TR-30648     1.2227      1.3909         1.2486         0.5770
# 3     TR-30930     1.2242      1.6788         1.2856         0.6397
# 4     TR-30948     1.2110      0.8036         1.1559         0.6466
# ...        ...        ...         ...            ...            ...
# 7467   TR-7468     1.2219         NaN         1.2413         0.5313
# 5768   TR-5769     1.2219         NaN         1.2413         0.5313
# 297     TR-298     1.3189      1.9318         1.9962         1.8431
# 8883   TR-8884     2.0254      1.8497         2.0042         1.9831
# 1691   TR-1692     1.2219         NaN         1.2413         0.5313
#
#       外資券商_分點出貨比(%)  外資券商_前1天分點進出  外資券商_前1天分點買賣力  外資券商_前1天分點成交力(%)  \
# 0            0.6408        1.2400         6.3132            1.4380
# ...

# %%
combined['飆股'].value_counts()
# Out:
# 飆股
# 1    1254
# 0    1254
# Name: count, dtype: int64

# %%
combined.to_feather('combined.feather')
combined
# Out:
#             ID  外資券商_分點進出  外資券商_分點買賣力  外資券商_分點成交力(%)  外資券商_分點吃貨比(%)  \
# 0       TR-191     1.9198      2.4793         1.9867         1.4249
# 1       TR-193     1.2219         NaN         1.2413         0.5313
# 2     TR-30648     1.2227      1.3909         1.2486         0.5770
# 3     TR-30930     1.2242      1.6788         1.2856         0.6397
# 4     TR-30948     1.2110      0.8036         1.1559         0.6466
# ...        ...        ...         ...            ...            ...
# 7467   TR-7468     1.2219         NaN         1.2413         0.5313
# 5768   TR-5769     1.2219         NaN         1.2413         0.5313
# 297     TR-298     1.3189      1.9318         1.9962         1.8431
# 8883   TR-8884     2.0254      1.8497         2.0042         1.9831
# 1691   TR-1692     1.2219         NaN         1.2413         0.5313
#
#       外資券商_分點出貨比(%)  外資券商_前1天分點進出  外資券商_前1天分點買賣力  外資券商_前1天分點成交力(%)  \
# 0            0.6408        1.2400         6.3132            1.4380
# ...
